# %%
from deep_agent_email_assistant import (
    create_email_agent,
    process_email,
    format_output,
    export_to_json,
)

# Create the agent
agent = create_email_agent()
    
# Process the latest email
result = process_email(
        agent,
        instruction="Read the latest email and compose a thoughtful response. Research any topics if needed.",
        verbose=True
    )
    
# Display results
print(format_output(result, show_files=False))
    
# Export to JSON
export_to_json(result)
    
# Access specific components
if result["draft"]:
        print("\n🎯 FINAL DRAFT:")
        print(result["draft"])
